# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate

summary_table_path = 'tableSummary.xlsx'
figure_dir_path = 'figures'
target_name = 'employee-recognition'
target_dir = os.path.join(figure_dir_path, target_name)
data = pd.read_excel(summary_table_path)[['Name', "Tag", "Location"]]


def search_by_name(name):
    name = name.replace('.xlsx', '')
    print(tabulate(data[lambda x: x['Name'].str.contains(name, case=False)], headers='keys', tablefmt='psql')) 

def search_by_tag(tag):
    print(tabulate(data[lambda x: x['Tag'].str.contains(tag, case=False)], headers='keys', tablefmt='psql'))

def display_all():
    print(tabulate(data, headers='keys', tablefmt='psql'))

def display_figure(name, tmp_display_dir='tmp_display'):
    name = name.strip()
    # Create a temporary directory to store the figures, tables and other files
    if not os.path.exists(tmp_display_dir):
        os.makedirs(tmp_display_dir)
    else:
        for file_name in os.listdir(tmp_display_dir):
            os.remove(os.path.join(tmp_display_dir, file_name))

    # Move the table to the temporary directory
    
    data_with_names =  data[data['Name'] == name]
    if len(data_with_names) == 0:
        print('No data found for the name: ', name)
        print('Similar names:')
        search_by_name(name)
        return
    
    if len(data_with_names) > 1:
        print('Multiple data found for the name: ', name)
        print('Please select one of the following: ')
        print(tabulate(data_with_names, headers='keys', tablefmt='psql'))
        return
    
    table_path = data_with_names['Location'].values[0]

    shutil.copy(table_path, os.path.join(tmp_display_dir, os.path.basename(table_path)))

    name = name.replace('.xlsx', '')
    for file_name in os.listdir(target_dir):
        if name == file_name.split('-')[0]:
            print('Figure found: ', file_name, '\nCopying to display directory')
            shutil.copy(os.path.join(target_dir, file_name), os.path.join(tmp_display_dir, file_name))

# %% [markdown]
# ## How to use
#
# - First, run `display_all()` for a glace of the whole table.
# - By calling `display_figure()` with a specified name, I will copy the table and figures to the a temporary directory for display.
# - To add tags or notes, please open `tableSumamry.xlsx` and manually add it, split with commas.
#
# Other functions
# - `search_by_name` displays all tables containing the input name.
# - `search_by_tag` displays all tables containing the input tag.

# %%
display_all()
# Out:
# +-----+------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------+
# |     | Name                                                                   | Tag                                                                                                                                                                                                                 | Location                                                                                              |
# |-----+------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------|
# |   0 | employee_attendance_record.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_attendance_record.xlsx                                        |
# |   1 | employee_attendance_tracker.xlsx                                       | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_attendance_tracker.xlsx                                       |
# |   2 | employee_or_independent_contractor_checklist.xlsx                      | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_or_independent_contractor_checklist.xlsx                      |
# |   3 | employee_timecard_daily_weekly_monthly_and_yearly.xlsx                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_timecard_daily_weekly_monthly_and_yearly.xlsx                 |
# |   4 | employee_timesheet_weekly_monthly_yearly.xlsx                          | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_timesheet_weekly_monthly_yearly.xlsx                          |
# |   5 | employee_absence_schedule.xlsx                                         | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_absence_schedule.xlsx                                         |
# |   6 | sales_receipt_with_logo.xlsx                                           | employee-recognition,employee-training,payroll,invoices,business_budgets,contests,gantt_charts,college_tools,student_awards_and_certificates,papers_and_reports,lesson_plans                                        | ./storage/employee-recognition/sales_receipt_with_logo.xlsx                                           |
# |   7 | time_card.xlsx                                                         | employee-recognition,employee-training,payroll,invoices,business_budgets,hiring_and_recruitment,business_time_sheets,agenda,college_tools,papers_and_reports,lesson_plans                                           | ./storage/employee-recognition/time_card.xlsx                                                         |
# |   8 | employee_shift_schedule.xlsx                                           | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/employee_shift_schedule.xlsx                                           |
# |   9 | job_candidates_tracker.xlsx                                            | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/job_candidates_tracker.xlsx                                            |
# |  10 | weekly_timesheet_8_12_x_11_portrait.xlsx                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/weekly_timesheet_8_12_x_11_portrait.xlsx                               |
# |  11 | shift_work_calendar.xlsx                                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/shift_work_calendar.xlsx                                               |
# |  12 | work_order_tracker.xlsx                                                | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/work_order_tracker.xlsx                                                |
# |  13 | weekly_time_record_small_business.xlsx                                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/weekly_time_record_small_business.xlsx                                 |
# |  14 | resume_wrangler.xlsx                                                   | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/resume_wrangler.xlsx                                                   |
# |  15 | sales_receipt_simple_design_worksheet.xlsx                             | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,contests,agenda,gantt_charts,college_tools,student_awards_and_certificates,papers_and_reports,lesson_plans                              | ./storage/employee-recognition/sales_receipt_simple_design_worksheet.xlsx                             |
# |  16 | volunteer_assignments.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/volunteer_assignments.xlsx                                             |
# |  17 | timesheet_worksheet.xlsx                                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/timesheet_worksheet.xlsx                                               |
# |  18 | biweekly_time_sheet_with_sick_leave_and_vacation_with_sample_data.xlsx | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/biweekly_time_sheet_with_sick_leave_and_vacation_with_sample_data.xlsx |
# |  19 | biweekly_time_sheet.xlsx                                               | employee-recognition,employee-training,payroll,invoices,business_budgets,hiring_and_recruitment,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                              | ./storage/employee-recognition/biweekly_time_sheet.xlsx                                               |
# |  20 | timesheet_weekly.xlsx                                                  | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/timesheet_weekly.xlsx                                                  |
# |  21 | my_military_service.xlsx                                               | employee-recognition,employee-training,invoices,business_budgets,hiring_and_recruitment,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                      | ./storage/employee-recognition/my_military_service.xlsx                                               |
# |  22 | invoice_worksheet.xlsx                                                 | employee-recognition,employee-training,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                     | ./storage/employee-recognition/invoice_worksheet.xlsx                                                 |
# |  23 | statement_of_account.xlsx                                              | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/statement_of_account.xlsx                                              |
# |  24 | elemental_timesheet.xlsx                                               | employee-recognition,employee-training,payroll,invoices,business_budgets,hiring_and_recruitment,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                              | ./storage/employee-recognition/elemental_timesheet.xlsx                                               |
# |  25 | class_attendance_list.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/class_attendance_list.xlsx                                             |
# |  26 | petty_cash_log.xlsx                                                    | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/petty_cash_log.xlsx                                                    |
# |  27 | weekly_timesheet.xlsx                                                  | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/weekly_timesheet.xlsx                                                  |
# |  28 | biweekly_timesheet_with_sick_leave_and_vacation.xlsx                   | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/biweekly_timesheet_with_sick_leave_and_vacation.xlsx                   |
# |  29 | weekly_time_sheet_8_12_x_11_landscape.xlsx                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/weekly_time_sheet_8_12_x_11_landscape.xlsx                             |
# |  30 | elemental_sales_receipt.xlsx                                           | employee-recognition,payroll,invoices,business_budgets,contests,agenda,gantt_charts,college_tools,student_awards_and_certificates,papers_and_reports,lesson_plans                                                   | ./storage/employee-recognition/elemental_sales_receipt.xlsx                                           |
# |  31 | allowance_tracker.xlsx                                                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/allowance_tracker.xlsx                                                 |
# |  32 | service_invoice_simple_design.xlsx                                     | employee-recognition,employee-training,payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                        | ./storage/employee-recognition/service_invoice_simple_design.xlsx                                     |
# |  33 | service_invoice_simple_design.xlsx                                     | employee-recognition,employee-training,payroll,invoices,business_budgets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                          | ./storage/employee-recognition/service_invoice_simple_design.xlsx                                     |
# |  34 | sales_invoice_simple_lines_design.xlsx                                 | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                     | ./storage/employee-recognition/sales_invoice_simple_lines_design.xlsx                                 |
# |  35 | project_tracker.xlsx                                                   | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/project_tracker.xlsx                                                   |
# |  36 | business_plan_checklist_with_swot_analysis.xlsx                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/business_plan_checklist_with_swot_analysis.xlsx                        |
# |  37 | service_invoice_simple_lines_design_worksheet.xlsx                     | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                       | ./storage/employee-recognition/service_invoice_simple_lines_design_worksheet.xlsx                     |
# |  38 | bill_paid_tracker.xlsx                                                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/bill_paid_tracker.xlsx                                                 |
# |  39 | team_roster_schedule_and_calendar.xlsx                                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/team_roster_schedule_and_calendar.xlsx                                 |
# |  40 | project_performance_report.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/project_performance_report.xlsx                                        |
# |  41 | idea_planner_tasks.xlsx                                                | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/idea_planner_tasks.xlsx                                                |
# |  42 | profit_and_loss_statement_with_logo.xlsx                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/profit_and_loss_statement_with_logo.xlsx                               |
# |  43 | manufacturer_defect_analysis.xlsx                                      | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/manufacturer_defect_analysis.xlsx                                      |
# |  44 | water_color_wash_invitation_tracker.xlsx                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/water_color_wash_invitation_tracker.xlsx                               |
# |  45 | disbursement_journal.xlsx                                              | employee-recognition,employee-training,payroll,invoices,business_budgets,business_time_sheets,contests,agenda,gantt_charts,college_tools,graduation,student_awards_and_certificates,papers_and_reports,lesson_plans | ./storage/employee-recognition/disbursement_journal.xlsx                                              |
# |  46 | service_invoice_simple.xlsx                                            | employee-recognition,invoices,business_budgets,agenda,gantt_charts,college_tools,student_awards_and_certificates,papers_and_reports,lesson_plans                                                                    | ./storage/employee-recognition/service_invoice_simple.xlsx                                            |
# |  47 | my_family's_health_record.xlsx                                         | employee-recognition,employee-training,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                           | ./storage/employee-recognition/my_family's_health_record.xlsx                                         |
# |  48 | check_register_ledger.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/check_register_ledger.xlsx                                             |
# |  49 | inventory_list_with_highlighting.xlsx                                  | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition/inventory_list_with_highlighting.xlsx                                  |
# |  50 | commercial_invoice.xlsx                                                | employee-recognition,payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                          | ./storage/employee-recognition\commercial_invoice.xlsx                                                |
# |  51 | inventory_list_with_reorder_highlighting.xlsx                          | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\inventory_list_with_reorder_highlighting.xlsx                          |
# |  52 | simple_invoice_that_calculates_total.xlsx                              | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,gantt_charts,papers_and_reports,lesson_plans                                                                                            | ./storage/employee-recognition\simple_invoice_that_calculates_total.xlsx                              |
# |  53 | sports_team_roster.xlsx                                                | employee-recognition,employee-training,business_budgets,hiring_and_recruitment,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                  | ./storage/employee-recognition\sports_team_roster.xlsx                                                |
# |  54 | check_register_with_chart.xlsx                                         | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\check_register_with_chart.xlsx                                         |
# |  55 | colorful_sales_invoice.xlsx                                            | employee-recognition,payroll,invoices,business_budgets,contests,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                 | ./storage/employee-recognition\colorful_sales_invoice.xlsx                                            |
# |  56 | check_register_simple_design.xlsx                                      | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\check_register_simple_design.xlsx                                      |
# |  57 | profit_loss_statement.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\profit_loss_statement.xlsx                                             |
# |  58 | manufacturing_output_chart.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\manufacturing_output_chart.xlsx                                        |
# |  59 | small_business_income_statement.xlsx                                   | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\small_business_income_statement.xlsx                                   |
# |  60 | meeting_agenda_with_adjustable_times.xlsx                              | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\meeting_agenda_with_adjustable_times.xlsx                              |
# |  61 | check_register_with_transaction_codes.xlsx                             | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                              | ./storage/employee-recognition\check_register_with_transaction_codes.xlsx                             |
# |  62 | ticket_sales_tracker.xlsx                                              | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\ticket_sales_tracker.xlsx                                              |
# |  63 | basic_business_invoice.xlsx                                            | employee-recognition,employee-training,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                     | ./storage/employee-recognition\basic_business_invoice.xlsx                                            |
# |  64 | profit_and_loss_income_statement.xlsx                                  | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\profit_and_loss_income_statement.xlsx                                  |
# |  65 | online_sales_tracker.xlsx                                              | employee-recognition,employee-training,payroll,invoices,business_budgets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                          | ./storage/employee-recognition\online_sales_tracker.xlsx                                              |
# |  66 | org_charts_visual.xlsx                                                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\org_charts_visual.xlsx                                                 |
# |  67 | basic_customer_contact_list.xlsx                                       | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\basic_customer_contact_list.xlsx                                       |
# |  68 | event_planner_and_timeline.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\event_planner_and_timeline.xlsx                                        |
# |  69 | sales_invoice_simple_design.xlsx                                       | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,contests,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                            | ./storage/employee-recognition\sales_invoice_simple_design.xlsx                                       |
# |  70 | expense_report.xlsx                                                    | employee-recognition,employee-training,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                     | ./storage/employee-recognition\expense_report.xlsx                                                    |
# |  71 | service_invoice_blocky_design.xlsx                                     | employee-recognition,payroll,invoices,business_budgets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                                            | ./storage/employee-recognition\service_invoice_blocky_design.xlsx                                     |
# |  72 | warehouse_inventory.xlsx                                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\warehouse_inventory.xlsx                                               |
# |  73 | check_register.xlsx                                                    | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\check_register.xlsx                                                    |
# |  74 | simple_invoice.xlsx                                                    | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                       | ./storage/employee-recognition\simple_invoice.xlsx                                                    |
# |  75 | small_business_profit_and_loss_statement.xlsx                          | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\small_business_profit_and_loss_statement.xlsx                          |
# |  76 | sales_leads_tracker.xlsx                                               | employee-recognition,invoices,business_budgets,hiring_and_recruitment,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                           | ./storage/employee-recognition\sales_leads_tracker.xlsx                                               |
# |  77 | quarterly_sale_report.xlsx                                             | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                       | ./storage/employee-recognition\quarterly_sale_report.xlsx                                             |
# |  78 | inventory_list_accessibility_guide.xlsx                                | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\inventory_list_accessibility_guide.xlsx                                |
# |  79 | sales_pipeline.xlsx                                                    | employee-recognition,invoices,business_budgets,hiring_and_recruitment,contests,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                    | ./storage/employee-recognition\sales_pipeline.xlsx                                                    |
# |  80 | monthly_personal_planner.xlsx                                          | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\monthly_personal_planner.xlsx                                          |
# |  81 | daily_appointment_calendar.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\daily_appointment_calendar.xlsx                                        |
# |  82 | small_business_sales_invoice.xlsx                                      | employee-recognition,payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                          | ./storage/employee-recognition\small_business_sales_invoice.xlsx                                      |
# |  83 | billing_statement_of_account.xlsx                                      | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                       | ./storage/employee-recognition\billing_statement_of_account.xlsx                                      |
# |  84 | simple_service_invoice.xlsx                                            | employee-recognition,employee-training,payroll,invoices,business_budgets,hiring_and_recruitment,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                 | ./storage/employee-recognition\simple_service_invoice.xlsx                                            |
# |  85 | billing_invoice.xlsx                                                   | employee-recognition,payroll,invoices,business_budgets,agenda,gantt_charts,college_tools,student_awards_and_certificates,papers_and_reports,lesson_plans                                                            | ./storage/employee-recognition\billing_invoice.xlsx                                                   |
# |  86 | sales_invoice_tracker.xlsx                                             | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                     | ./storage/employee-recognition\sales_invoice_tracker.xlsx                                             |
# |  87 | small_business_sales_lead_tracker.xlsx                                 | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\small_business_sales_lead_tracker.xlsx                                 |
# |  88 | billing_statement.xlsx                                                 | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                       | ./storage/employee-recognition\billing_statement.xlsx                                                 |
# |  89 | event_planning_tracker.xlsx                                            | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\event_planning_tracker.xlsx                                            |
# |  90 | business_price_quotation.xlsx                                          | employee-recognition,payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports                                                                                                                       | ./storage/employee-recognition\business_price_quotation.xlsx                                          |
# |  91 | project_plan_for_law_firms.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\project_plan_for_law_firms.xlsx                                        |
# |  92 | simple_business_invoice.xlsx                                           | employee-recognition,payroll,invoices,business_budgets,agenda,college_tools,papers_and_reports,lesson_plans                                                                                                         | ./storage/employee-recognition\simple_business_invoice.xlsx                                           |
# |  93 | simple_sale_invoice.xlsx                                               | employee-recognition,payroll,invoices,business_budgets,contests,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                 | ./storage/employee-recognition\simple_sale_invoice.xlsx                                               |
# |  94 | daily_checklist_challenge.xlsx                                         | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\daily_checklist_challenge.xlsx                                         |
# |  95 | party_planner_and_checklist.xlsx                                       | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\party_planner_and_checklist.xlsx                                       |
# |  96 | work_plan_timeline.xlsx                                                | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\work_plan_timeline.xlsx                                                |
# |  97 | invoices_tracker.xlsx                                                  | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                     | ./storage/employee-recognition\invoices_tracker.xlsx                                                  |
# |  98 | social_media_engagement_data.xlsx                                      | employee-recognition,business_budgets,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                  | ./storage/employee-recognition\social_media_engagement_data.xlsx                                      |
# |  99 | gantt_project_planner.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\gantt_project_planner.xlsx                                             |
# | 100 | weekly_schedule_planner.xlsx                                           | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\weekly_schedule_planner.xlsx                                           |
# | 101 | retirement_planner.xlsx                                                | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\retirement_planner.xlsx                                                |
# | 102 | check_register_with_spending_summary.xlsx                              | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\check_register_with_spending_summary.xlsx                              |
# | 103 | contact_list.xlsx                                                      | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\contact_list.xlsx                                                      |
# | 104 | billing_statement_simple.xlsx                                          | employee-recognition,payroll,invoices,business_budgets,business_time_sheets,contests,agenda,gantt_charts,college_tools,student_awards_and_certificates,papers_and_reports,lesson_plans                              | ./storage/employee-recognition\billing_statement_simple.xlsx                                          |
# | 105 | daily_task_list.xlsx                                                   | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\daily_task_list.xlsx                                                   |
# | 106 | equipment_inventory_and_depreciation_schedule.xlsx                     | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\equipment_inventory_and_depreciation_schedule.xlsx                     |
# | 107 | household_organizer.xlsx                                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\household_organizer.xlsx                                               |
# | 108 | assignment_schedule.xlsx                                               | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\assignment_schedule.xlsx                                               |
# | 109 | equipment_inventory_list.xlsx                                          | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\equipment_inventory_list.xlsx                                          |
# | 110 | idea_planner.xlsx                                                      | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\idea_planner.xlsx                                                      |
# | 111 | budget_summary_report.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/employee-recognition\budget_summary_report.xlsx                                             |
# | 112 | service_invoice_with_tax_calculations.xlsx                             | payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                               | ./storage/invoce\service_invoice_with_tax_calculations.xlsx                                           |
# | 113 | basic_invoice.xlsx                                                     | lesson_plans                                                                                                                                                                                                        | ./storage/invoce\basic_invoice.xlsx                                                                   |
# | 114 | invoice_with_finance_charge.xlsx                                       | payroll,invoices,business_budgets,agenda,papers_and_reports,lesson_plans                                                                                                                                            | ./storage/invoce\invoice_with_finance_charge.xlsx                                                     |
# | 115 | basic_invoice_with_unit_price.xlsx                                     | payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                               | ./storage/invoce\basic_invoice_with_unit_price.xlsx                                                   |
# | 116 | invoice_with_tax_calculation.xlsx                                      | payroll,invoices,business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                               | ./storage/invoce\invoice_with_tax_calculation.xlsx                                                    |
# ...
# | 316 | monthly_budget_accessibility_guide.xlsx                                | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\monthly_budget_accessibility_guide.xlsx                                             |
# | 317 | wedding_budget_template.xlsx                                           | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\wedding_budget_template.xlsx                                                        |
# | 318 | trip_planner_worksheet.xlsx                                            | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\trip_planner_worksheet.xlsx                                                         |
# | 319 | detailed_project_timeline.xlsx                                         | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\detailed_project_timeline.xlsx                                                      |
# | 320 | bathroom_remodel_cost_calculator.xlsx                                  | business_budgets,papers_and_reports,lesson_plans                                                                                                                                                                    | ./storage/payroll\bathroom_remodel_cost_calculator.xlsx                                               |
# | 321 | rent_affordability_calculator.xlsx                                     | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\rent_affordability_calculator.xlsx                                                  |
# | 322 | weekly_college_schedule.xlsx                                           | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\weekly_college_schedule.xlsx                                                        |
# | 323 | project_timeline_with_milestones.xlsx                                  | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\project_timeline_with_milestones.xlsx                                               |
# | 324 | milestone_and_task_project_timeline.xlsx                               | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\milestone_and_task_project_timeline.xlsx                                            |
# | 325 | simple_calendar.xlsx                                                   | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\simple_calendar.xlsx                                                                |
# | 326 | my_class_schedule.xlsx                                                 | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\my_class_schedule.xlsx                                                              |
# | 327 | run_chart.xlsx                                                         | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\run_chart.xlsx                                                                      |
# | 328 | event_schedule.xlsx                                                    | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\event_schedule.xlsx                                                                 |
# | 329 | college_comparison_tracker.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\college_comparison_tracker.xlsx                                                     |
# | 330 | fitness_plan.xlsx                                                      | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\fitness_plan.xlsx                                                                   |
# | 331 | basic_medication_log.xlsx                                              | business_budgets,business_time_sheets,agenda,gantt_charts,college_tools,papers_and_reports,lesson_plans                                                                                                             | ./storage/payroll\basic_medication_log.xlsx                                                           |
# | 332 | project_issue_tracker.xlsx                                             | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\project_issue_tracker.xlsx                                                          |
# | 333 | streaming_show_list.xlsx                                               | business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                           | ./storage/payroll\streaming_show_list.xlsx                                                            |
# | 334 | exercise_planner.xlsx                                                  | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\exercise_planner.xlsx                                                               |
# | 335 | fitness_vision.xlsx                                                    | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\fitness_vision.xlsx                                                                 |
# | 336 | diet_and_exercise_journal.xlsx                                         | business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                           | ./storage/payroll\diet_and_exercise_journal.xlsx                                                      |
# | 337 | gas_mileage_tracker.xlsx                                               | business_budgets,agenda,gantt_charts,papers_and_reports                                                                                                                                                             | ./storage/payroll\gas_mileage_tracker.xlsx                                                            |
# | 338 | personal_mileage_tracker.xlsx                                          | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\personal_mileage_tracker.xlsx                                                       |
# | 339 | weight_loss_tracker.xlsx                                               | business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                                | ./storage/payroll\weight_loss_tracker.xlsx                                                            |
# | 340 | wedding_invitation_tracker.xlsx                                        | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\wedding_invitation_tracker.xlsx                                                     |
# | 341 | fitness_tracker.xlsx                                                   | employee-training,business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                         | ./storage/payroll\fitness_tracker.xlsx                                                                |
# | 342 | calorie_amortization_schedule.xlsx                                     | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\calorie_amortization_schedule.xlsx                                                  |
# | 343 | baby_growth_chart.xlsx                                                 | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\baby_growth_chart.xlsx                                                              |
# | 344 | baby_growth_tracker.xlsx                                               | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\baby_growth_tracker.xlsx                                                            |
# | 345 | teacher's_grade_book_based_on_averages.xlsx                            | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\teacher's_grade_book_based_on_averages.xlsx                                         |
# | 346 | graph_paper.xlsx                                                       | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\graph_paper.xlsx                                                                    |
# | 347 | blood_pressure_and_glucose_tracker.xlsx                                | business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                           | ./storage/payroll\blood_pressure_and_glucose_tracker.xlsx                                             |
# | 348 | activity_tracker.xlsx                                                  | business_budgets,business_time_sheets,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                  | ./storage/payroll\activity_tracker.xlsx                                                               |
# | 349 | daily_log_of_calories_and_fat_percentage.xlsx                          | business_budgets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                                | ./storage/payroll\daily_log_of_calories_and_fat_percentage.xlsx                                       |
# | 350 | teacher's_grade_book_based_on_percentages.xlsx                         | lesson_plans                                                                                                                                                                                                        | ./storage/payroll\teacher's_grade_book_based_on_percentages.xlsx                                      |
# | 351 | blood_pressure_tracker.xlsx                                            | business_budgets,business_time_sheets,agenda,gantt_charts,papers_and_reports,lesson_plans                                                                                                                           | ./storage/payroll\blood_pressure_tracker.xlsx                                                         |
# | 352 | blood_sugar_tracker.xlsx                                               | business_budgets,business_time_sheets,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                  | ./storage/payroll\blood_sugar_tracker.xlsx                                                            |
# | 353 | date_tracker_gantt_chart.xlsx                                          | business_budgets,business_time_sheets,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                  | ./storage/payroll\date_tracker_gantt_chart.xlsx                                                       |
# | 354 | sudoku_game.xlsx                                                       | business_budgets,contests,gantt_charts,papers_and_reports,lesson_plans                                                                                                                                              | ./storage/payroll\sudoku_game.xlsx                                                                    |
# +-----+------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------+

# %%
# Suppose we want to take a glance at `employee_attendance_record.xlsx `
display_target = 'employee_attendance_record.xlsx'
display_figure(display_target)
# Out:
# Figure found:  employee_attendance_record-Calendar View.png
# Copying to display directory
# Figure found:  employee_attendance_record-Company Holidays.png
# Copying to display directory
# Figure found:  employee_attendance_record-Employee Leave Tracker.png
# Copying to display directory
# Figure found:  employee_attendance_record-Leave Types.png
# Copying to display directory
# Figure found:  employee_attendance_record-List of Employees.png
# Copying to display directory
